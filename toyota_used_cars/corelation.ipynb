# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
ca_cars = pd.read_csv('/Users/vj/Documents/Data/toyota_used_cars/ca_toyota_used_cars.csv')
ca_cars
# Out:
#       Unnamed: 0  Price  Year  Mileage      Model
# 0             87  12499  2016    11399  CorollaLE
# 1            103  11500  2016    37160  CorollaLE
# 2            140  11499  2015    17395  CorollaLE
# 3            176  13491  2016    11582   CorollaL
# 4            213  11499  2015    19639  CorollaLE
# ...          ...    ...   ...      ...        ...
# 9174       77643  43326  2015    20803     Tundra
# 9175       77648  67500  2016    10068     Tundra
# 9176       77649  62477  2016    35715       Land
# 9177       77687  74999  2017     8296       Land
# 9178       77703  79991  2017     6966       Land
#
# [9179 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load and process the data
ca_cars = pd.read_csv('ca_toyota_used_cars.csv')

# Add car age as a feature
current_year = 2024
ca_cars['Car Age'] = current_year - ca_cars['Year']
ca_cars.drop('Year', axis=1, inplace=True)

# Select only numerical columns
numerical_features = ['Price', 'Car Age', 'Mileage']

# Compute the correlation matrix for numerical features
corr = ca_cars[numerical_features].corr()

# Generate a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# Market Trends based on Car Age
ca_cars['Car Age'] = current_year - ca_cars['Year']
average_price_by_age = ca_cars.groupby('Car Age')['Price'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='Car Age', y='Price', data=average_price_by_age)
plt.xlabel('Car Age')
plt.ylabel('Average Price')
plt.title('Market Trends: Average Price by Car Age')
plt.show()

# %%
# Impact of Mileage on Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Mileage', y='Price', data=ca_cars)
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.title('Impact of Mileage on Price')
plt.show()
